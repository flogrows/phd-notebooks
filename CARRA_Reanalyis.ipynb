# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# %%
filenames = glob("/home/eefjg/OneDrive/Leeds/PhD/Data/CARRA/*.nc")

# %%
ds = xr.open_mfdataset(filenames, combine='by_coords')
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 365, y: 1269, x: 1069)
# Coordinates:
#   * time        (time) datetime64[ns] 2022-01-01T15:00:00 ... 2022-12-31T15:0...
#     step        timedelta64[ns] 00:00:00
#     surface     float64 0.0
#     latitude    (y, x) float64 dask.array<chunksize=(1269, 1069), meta=np.ndarray>
#     longitude   (y, x) float64 dask.array<chunksize=(1269, 1069), meta=np.ndarray>
#     valid_time  (time) datetime64[ns] dask.array<chunksize=(365,), meta=np.ndarray>
# Dimensions without coordinates: y, x
# Data variables:
#     lsm         (time, y, x) float32 dask.array<chunksize=(365, 1269, 1069), meta=np.ndarray>
#     siconc      (time, y, x) float32 dask.array<chunksize=(365, 1269, 1069), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             enmi
#     GRIB_centreDescription:  Oslo
#     GRIB_subCentre:          255
#     Conventions:             CF-1.7
#     institution:             Oslo
# ...

# %%
ds['siconc'].sel(time='2022-03-14').plot()
